# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import GEOparse as Geo
import seaborn as sns
os.getcwd()
# Out:
# '/home/max/mcrc-cetuximab-analysis/notebooks'

# %%
gse = Geo.get_GEO(filepath="../raw/GSE183984_family.soft", silent=True)
print(gse.gpls)
for key in gse.gsms:
    df = pd.DataFrame(columns=gse.gsms[key].metadata.keys())
    break

for key in gse.gsms:
    df = pd.concat([df, pd.DataFrame([gse.gsms[key].metadata], index=[key])])

df.to_csv("../data/ann.csv", index=True)

df = pd.read_csv("../data/ann.csv")
df = df.rename(columns={'Unnamed: 0': 'sample_id'})
df = df.set_index('sample_id')

df.to_csv("../data/ann.csv", index=True)

df
# Out:
# {'GPL16791': <d: GPL16791>}
#                                       title   geo_accession  \
# sample_id
# GSM5575333      ['POST-R-001 [18R649_010]']  ['GSM5575333']
# GSM5575334  ['PAIR-R-001-pre  [18R654_15]']  ['GSM5575334']
# GSM5575335      ['PAIR-R-001 [18R655_016]']  ['GSM5575335']
# GSM5575336       ['POST-R-002 [18R669_01]']  ['GSM5575336']
# GSM5575337       ['PAIR-R-002 [18R670_02]']  ['GSM5575337']
# ...                                     ...             ...
# GSM5575441       ['PRE-R-051 [18R454_027]']  ['GSM5575441']
# GSM5575442       ['PRE-R-052 [18R477_019]']  ['GSM5575442']
# GSM5575443          ['PRE-10 [18R507_004]']  ['GSM5575443']
# GSM5575444       ['PRE-R-054 [18R428_008]']  ['GSM5575444']
# GSM5575445       ['PRE-R-055 [18R705_013]']  ['GSM5575445']
#
#                                status  submission_date last_update_date  \
# sample_id
# GSM5575333  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575334  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575335  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575336  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575337  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# ...                               ...              ...              ...
# GSM5575441  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575442  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575443  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575444  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575445  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
#
#                type channel_count        source_name_ch1      organism_ch1  \
# sample_id
# GSM5575333  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575334  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575335  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575336  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575337  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# ...             ...           ...                    ...               ...
# GSM5575441  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575442  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575443  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575444  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575445  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
#
#            taxid_ch1  ... contact_zip/postal_code  contact_country  \
# sample_id             ...
# GSM5575333  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575334  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575335  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575336  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575337  ['9606']  ...               ['05505']  ['South Korea']
# ...              ...  ...                     ...              ...
# GSM5575441  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575442  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575443  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575444  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575445  ['9606']  ...               ['05505']  ['South Korea']
#
#                    instrument_model library_selection      library_source  \
# sample_id
# GSM5575333  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575334  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575335  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575336  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575337  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# ...                             ...               ...                 ...
# GSM5575441  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575442  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575443  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575444  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575445  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
#
#            library_strategy  \
# sample_id
# GSM5575333      ['RNA-Seq']
# GSM5575334      ['RNA-Seq']
# GSM5575335      ['RNA-Seq']
# GSM5575336      ['RNA-Seq']
# GSM5575337      ['RNA-Seq']
# ...                     ...
# GSM5575441      ['RNA-Seq']
# GSM5575442      ['RNA-Seq']
# GSM5575443      ['RNA-Seq']
# GSM5575444      ['RNA-Seq']
# GSM5575445      ['RNA-Seq']
#
#                                                      relation  \
# sample_id
# GSM5575333  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575334  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575335  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575336  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575337  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# ...                                                       ...
# GSM5575441  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575442  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575443  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575444  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575445  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
#
#            supplementary_file_1      series_id data_row_count
# sample_id
# GSM5575333             ['NONE']  ['GSE183984']          ['0']
# GSM5575334             ['NONE']  ['GSE183984']          ['0']
# GSM5575335             ['NONE']  ['GSE183984']          ['0']
# GSM5575336             ['NONE']  ['GSE183984']          ['0']
# GSM5575337             ['NONE']  ['GSE183984']          ['0']
# ...                         ...            ...            ...
# GSM5575441             ['NONE']  ['GSE183984']          ['0']
# GSM5575442             ['NONE']  ['GSE183984']          ['0']
# GSM5575443             ['NONE']  ['GSE183984']          ['0']
# GSM5575444             ['NONE']  ['GSE183984']          ['0']
# GSM5575445             ['NONE']  ['GSE183984']          ['0']
#
# [113 rows x 31 columns]

# %%
df = pd.read_csv("../data/ann.csv")
ann = df.set_index('sample_id')
ann
# Out:
#                                       title   geo_accession  \
# sample_id
# GSM5575333      ['POST-R-001 [18R649_010]']  ['GSM5575333']
# GSM5575334  ['PAIR-R-001-pre  [18R654_15]']  ['GSM5575334']
# GSM5575335      ['PAIR-R-001 [18R655_016]']  ['GSM5575335']
# GSM5575336       ['POST-R-002 [18R669_01]']  ['GSM5575336']
# GSM5575337       ['PAIR-R-002 [18R670_02]']  ['GSM5575337']
# ...                                     ...             ...
# GSM5575441       ['PRE-R-051 [18R454_027]']  ['GSM5575441']
# GSM5575442       ['PRE-R-052 [18R477_019]']  ['GSM5575442']
# GSM5575443          ['PRE-10 [18R507_004]']  ['GSM5575443']
# GSM5575444       ['PRE-R-054 [18R428_008]']  ['GSM5575444']
# GSM5575445       ['PRE-R-055 [18R705_013]']  ['GSM5575445']
#
#                                status  submission_date last_update_date  \
# sample_id
# GSM5575333  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575334  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575335  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575336  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575337  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# ...                               ...              ...              ...
# GSM5575441  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575442  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575443  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575444  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
# GSM5575445  ['Public on Sep 16 2021']  ['Sep 12 2021']  ['Sep 16 2021']
#
#                type channel_count        source_name_ch1      organism_ch1  \
# sample_id
# GSM5575333  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575334  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575335  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575336  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575337  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# ...             ...           ...                    ...               ...
# GSM5575441  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575442  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575443  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575444  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
# GSM5575445  ['SRA']         ['1']  ['colorectal cancer']  ['Homo sapiens']
#
#            taxid_ch1  ... contact_zip/postal_code  contact_country  \
# sample_id             ...
# GSM5575333  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575334  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575335  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575336  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575337  ['9606']  ...               ['05505']  ['South Korea']
# ...              ...  ...                     ...              ...
# GSM5575441  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575442  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575443  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575444  ['9606']  ...               ['05505']  ['South Korea']
# GSM5575445  ['9606']  ...               ['05505']  ['South Korea']
#
#                    instrument_model library_selection      library_source  \
# sample_id
# GSM5575333  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575334  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575335  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575336  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575337  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# ...                             ...               ...                 ...
# GSM5575441  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575442  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575443  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575444  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
# GSM5575445  ['Illumina HiSeq 2500']          ['cDNA']  ['transcriptomic']
#
#            library_strategy  \
# sample_id
# GSM5575333      ['RNA-Seq']
# GSM5575334      ['RNA-Seq']
# GSM5575335      ['RNA-Seq']
# GSM5575336      ['RNA-Seq']
# GSM5575337      ['RNA-Seq']
# ...                     ...
# GSM5575441      ['RNA-Seq']
# GSM5575442      ['RNA-Seq']
# GSM5575443      ['RNA-Seq']
# GSM5575444      ['RNA-Seq']
# GSM5575445      ['RNA-Seq']
#
#                                                      relation  \
# sample_id
# GSM5575333  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575334  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575335  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575336  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575337  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# ...                                                       ...
# GSM5575441  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575442  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575443  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575444  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
# GSM5575445  ['BioSample: https://www.ncbi.nlm.nih.gov/bios...
#
#            supplementary_file_1      series_id data_row_count
# sample_id
# GSM5575333             ['NONE']  ['GSE183984']          ['0']
# GSM5575334             ['NONE']  ['GSE183984']          ['0']
# GSM5575335             ['NONE']  ['GSE183984']          ['0']
# GSM5575336             ['NONE']  ['GSE183984']          ['0']
# GSM5575337             ['NONE']  ['GSE183984']          ['0']
# ...                         ...            ...            ...
# GSM5575441             ['NONE']  ['GSE183984']          ['0']
# GSM5575442             ['NONE']  ['GSE183984']          ['0']
# GSM5575443             ['NONE']  ['GSE183984']          ['0']
# GSM5575444             ['NONE']  ['GSE183984']          ['0']
# GSM5575445             ['NONE']  ['GSE183984']          ['0']
#
# [113 rows x 31 columns]

# %%
for col in df.columns:
    cts = df[col].value_counts()
    if len(cts) > 1:
        print(cts)
    print('========================================================================================')
# Out:
# sample_id
# GSM5575333    1
# GSM5575390    1
# GSM5575416    1
# GSM5575415    1
# GSM5575414    1
#              ..
# GSM5575367    1
# GSM5575366    1
# GSM5575365    1
# GSM5575364    1
# GSM5575445    1
# Name: count, Length: 113, dtype: int64
# ========================================================================================
# title
# ['POST-R-001 [18R649_010]']     1
# ['POST-R-013 [18R653_014]']     1
# ['PRE-R-033 [18R457_023]']      1
# ['PRE-R-032 [18R456_002]']      1
# ['PRE-R-031 [18R440_020]']      1
#                                ..
# ['PAIR-39 [18R318_0005]']       1
# ['PAIR-R-011 [18R179_0023]']    1
# ['PAIR-32 [18R296_0008]']       1
# ['PAIR-R-010 [18R175_0011]']    1
# ['PRE-R-055 [18R705_013]']      1
# Name: count, Length: 113, dtype: int64
# ========================================================================================
# geo_accession
# ['GSM5575333']    1
# ['GSM5575390']    1
# ['GSM5575416']    1
# ['GSM5575415']    1
# ['GSM5575414']    1
#                  ..
# ['GSM5575367']    1
# ['GSM5575366']    1
# ['GSM5575365']    1
# ['GSM5575364']    1
# ['GSM5575445']    1
# Name: count, Length: 113, dtype: int64
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# characteristics_ch1
# ['tissue: primary tumor (colorectum)', 'time point: pre-treatment', 'treatment response: pre-Tx']             69
# ['tissue: liver metastases', 'time point: post-treatment', 'treatment response: post-tx PD']                  12
# ['tissue: primary tumor (colorectum)', 'time point: post-treatment', 'treatment response: post-Tx non-PD']    10
# ['tissue: liver metastases', 'time point: post-treatment', 'treatment response: post-Tx non-PD']               6
# ['tissue: primary tumor (colorectum)', 'time point: post-treatment', 'treatment response: post-tx PD']         5
# ['tissue: liver metastases', 'time point: pre-treatment', 'treatment response: pre-Tx']                        3
# ['tissue: lung metastases', 'time point: post-treatment', 'treatment response: post-tx PD']                    2
# ['tissue: lung metastases', 'time point: pre-treatment', 'treatment response: pre-Tx']                         2
# ['tissue: primary tumor (colorectum)', 'treatment response: pre-Tx']                                           1
# ['tissue: peritoneal metastases', 'time point: post-treatment', 'treatment response: post-tx PD']              1
# ['tissue: other site metastases', 'time point: post-treatment', 'treatment response: post-tx PD']              1
# ['tissue: other site metastases', 'time point: pre-treatment', 'treatment response: pre-Tx']                   1
# Name: count, dtype: int64
# ========================================================================================
# ========================================================================================
# ========================================================================================
# description
# ['18R649_010']     1
# ['18R653_014']     1
# ['18R457_023']     1
# ['18R456_002']     1
# ['18R440_020']     1
#                   ..
# ['18R318_0005']    1
# ['18R179_0023']    1
# ['18R296_0008']    1
# ['18R175_0011']    1
# ['18R705_013']     1
# Name: count, Length: 113, dtype: int64
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================
# relation
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398805', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12150946']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398774', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12150955']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398798', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151005']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398797', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151004']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398796', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151003']    1
#                                                                                                                                ..
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398749', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151042']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398748', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151041']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398747', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151040']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398746', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151039']    1
# ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN21398744', 'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX12151034']    1
# Name: count, Length: 113, dtype: int64
# ========================================================================================
# ========================================================================================
# ========================================================================================
# ========================================================================================

# %%
import pandas as pd
def decouple(s):
    ls = list(s.split("', '"))
    if len(ls) == 3:
        ls[0] = ls[0][2:]
        ls[2] = ls[2][:-2]
    elif len(ls) == 2:
        ls[0] = ls[0][2:]
        ls[1] = ls[1][:-2]
    dc = {s.split(': ')[0]: s.split(': ')[1] for s in ls}
    return dc

def pad_zeros(s, n):
    while len(s) < n:
        s = '0' + s
    return s

new_ann = pd.DataFrame(columns=['some_id', 'sample_title', 'tissue', 'time point', 'treatment response'])
for i in range(len(ann)):
    new_row = decouple(ann.iloc[i]['characteristics_ch1'])
    title = ann.iloc[i]['title']
    new_row['some_id'] = title[title.find('[', 1) + 1 : title.find(']')]
    new_row['sample_title'] = title[2:title.find(' ')]
    # new_row['sample_prefix'] = (lambda s: s[:s.find('-')])(new_row['sample_title'])
    new_row['patient_id'] = (lambda s: pad_zeros(''.join(filter(lambda x: x.isdigit(), s)), 4))(new_row['sample_title'])
    new_ann = pd.concat([new_ann, pd.DataFrame([new_row], index=[ann.index[i]])])

ann = new_ann

# %%
ann.to_csv('../data/useful_ann.csv')

# %%
ann = new_ann

# %%
ann['tissue'].value_counts()
# Out:
# tissue
# primary tumor (colorectum)    85
# liver metastases              21
# lung metastases                4
# other site metastases          2
# peritoneal metastases          1
# Name: count, dtype: int64

# %%
ann['time point'].value_counts()
# Out:
# time point
# pre-treatment     75
# post-treatment    37
# Name: count, dtype: int64

# %%
ann['treatment response'].value_counts()
# Out:
# treatment response
# pre-Tx            76
# post-tx PD        21
# post-Tx non-PD    16
# Name: count, dtype: int64

# %%
ann['sample_title'].value_counts().sort_index()
# Out:
# sample_title
# PAIR-04      1
# PAIR-28      2
# PAIR-29      1
# PAIR-32      1
# PAIR-39      1
#             ..
# PRE-R-050    1
# PRE-R-051    1
# PRE-R-052    1
# PRE-R-054    1
# PRE-R-055    1
# Name: count, Length: 97, dtype: int64

# %%
ann['patient_id'].value_counts().sort_index()
# Out:
# patient_id
# 0001    4
# 0002    4
# 0003    4
# 0004    4
# 0005    4
# 0006    4
# 0007    3
# 0008    4
# 0009    2
# 0010    4
# 0011    3
# 0012    4
# 0013    4
# 0014    4
# 0015    5
# 0016    4
# 0017    2
# 0018    3
# 0019    3
# 0020    3
# 0021    3
# 0022    1
# 0023    1
# 0024    1
# 0026    1
# 0027    1
# 0028    3
# 0029    2
# 0030    1
# 0031    1
# 0032    2
# 0033    1
# 0034    1
# 0035    1
# 0036    1
# 0037    1
# 0038    1
# 0039    2
# 0040    1
# 0041    1
# 0042    1
# 0043    1
# 0044    1
# 0045    1
# 0046    1
# 0047    1
# 0048    1
# 0049    1
# 0050    1
# 0051    1
# 0052    1
# 0054    1
# 0055    1
# 0061    1
# Name: count, dtype: int64
